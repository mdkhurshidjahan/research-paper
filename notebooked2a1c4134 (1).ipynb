jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0121.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0289.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0109.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0264.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0070.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0175.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0284.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0255.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0136.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0295.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0161.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0265.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0216.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0221.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0181.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0017.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0291.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0242.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0083.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0133.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0195.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0225.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0178.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0222.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0141.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0251.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0261.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0164.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0296.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0193.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0236.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0167.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0104.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0223.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0022.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0069.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0237.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0131.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0149.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0177.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0057.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0184.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0116.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0240.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0025.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0135.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0180.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0171.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0053.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0294.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0105.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0115.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0137.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0058.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0262.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0197.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0145.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0047.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0086.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0271.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0011.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0024.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0067.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0257.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0140.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0183.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0148.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0094.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0012.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0021.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0041.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0000.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0005.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0112.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0084.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0273.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0093.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0247.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0207.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0060.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0283.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0102.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0143.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0224.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0077.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0068.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0042.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0124.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0208.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0152.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0258.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0103.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0054.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0006.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0134.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0156.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0274.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0229.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0051.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0287.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0279.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0191.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0122.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0232.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0045.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0154.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0055.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0194.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0127.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0198.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0098.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0213.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0082.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0218.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0037.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0029.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0190.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0119.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0032.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0002.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0253.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0204.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0090.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0013.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0095.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0285.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0036.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0129.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0286.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0214.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0298.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0267.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0176.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0065.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0081.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0101.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0217.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0254.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0076.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0147.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0111.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0158.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0040.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0227.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0088.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0189.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0202.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0089.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0142.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0220.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0200.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0270.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0107.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0288.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0108.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0004.jpg
# /kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0250.jpg

# %% [markdown]
# ****xception****

# %%
import os
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras import regularizers

sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# Paths to your training and testing data
train_data_path = '/kaggle/input/brain-tumor-mri-dataset/Training'
test_data_path = '/kaggle/input/brain-tumor-mri-dataset/Testing'

# Create dataframes for training and testing data
def create_dataframe(data_path):
    filepaths = []
    labels = []
    folds = os.listdir(data_path)
    for fold in folds:
        f_path = os.path.join(data_path, fold)
        filelists = os.listdir(f_path)
        for file in filelists:
            filepaths.append(os.path.join(f_path, file))
            labels.append(fold)
    Fseries = pd.Series(filepaths, name='filepaths')
    Lseries = pd.Series(labels, name='label')
    return pd.concat([Fseries, Lseries], axis=1)

train_df = create_dataframe(train_data_path)
test_df = create_dataframe(test_data_path)

# Split test data into validation and test sets
valid, test = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=42)

img_size = (224, 224)
batch_size = 16

# ImageDataGenerators
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
valid_gen = ts_gen.flow_from_dataframe(valid, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen = ts_gen.flow_from_dataframe(test, x_col='filepaths', y_col='label', target_size=img_size,
                                      class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)

img_shape = (img_size[0], img_size[1], 3)
classes = train_gen.class_indices
num_class = len(classes)

# Using Xception as base model
base_model = tf.keras.applications.Xception(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(256, kernel_regularizer=regularizers.l2(0.016), activity_regularizer=regularizers.l1(0.006),
          bias_regularizer=regularizers.l1(0.006), activation='relu'),
    Dropout(rate=0.4, seed=75),
    Dense(num_class, activation='softmax')
])

model.compile(Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc = model.evaluate(test_gen, verbose=0)
        print(f'\nTesting loss: {test_loss}, Testing accuracy: {test_acc}\n')

Epochs = 30
history = model.fit(x=train_gen, epochs=Epochs, verbose=1, validation_data=valid_gen,
                    validation_steps=None, shuffle=False, callbacks=[TestAccuracyCallback()])

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i + 1 for i in range(len(train_acc))]

loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'

# Training history
plt.figure(figsize=(20, 8))
plt.style.use('ggplot')

plt.subplot(1, 2, 1)
plt.plot(Epochs, train_loss, 'r', label='Training Loss')
plt.plot(Epochs, val_loss, 'g', label='Validation Loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, train_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, val_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
30
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9479 - loss: 0.3715
# Testing loss: 0.25579285621643066, Testing accuracy: 0.9862805008888245
#
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 55s 153ms/step - accuracy: 0.9479 - loss: 0.3715 - val_accuracy: 0.9893 - val_loss: 0.2459
# Epoch 30/30
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9363 - loss: 0.3832
# Testing loss: 0.2445995807647705, Testing accuracy: 0.9923780560493469
#
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 55s 153ms/step - accuracy: 0.9363 - loss: 0.3832 - val_accuracy: 0.9847 - val_loss: 0.2561
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.2169
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9845 - loss: 0.2611
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9945 - loss: 0.2420
# Train Loss:  0.21695193648338318
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.24772381782531738
# Validation Accuracy:  0.98828125
# --------------------
# Test Loss:  0.24359717965126038
# Test Accuracy:  0.9921875
#  5/41 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# W0000 00:00:1718078666.871448     114 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.99      0.99       149
#   meningioma       0.99      0.98      0.98       148
#      notumor       1.00      1.00      1.00       208
#    pituitary       1.00      0.99      1.00       151
#
#     accuracy                           0.99       656
#    macro avg       0.99      0.99      0.99       656
# weighted avg       0.99      0.99      0.99       656

# %% [markdown]
# resnet50

# %%
import os
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras import regularizers

sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# Paths to your training and testing data
train_data_path = '/kaggle/input/brain-tumor-mri-dataset/Training'
test_data_path = '/kaggle/input/brain-tumor-mri-dataset/Testing'

# Create dataframes for training and testing data
def create_dataframe(data_path):
    filepaths = []
    labels = []
    folds = os.listdir(data_path)
    for fold in folds:
        f_path = os.path.join(data_path, fold)
        filelists = os.listdir(f_path)
        for file in filelists:
            filepaths.append(os.path.join(f_path, file))
            labels.append(fold)
    Fseries = pd.Series(filepaths, name='filepaths')
    Lseries = pd.Series(labels, name='label')
    return pd.concat([Fseries, Lseries], axis=1)

train_df = create_dataframe(train_data_path)
test_df = create_dataframe(test_data_path)

# Split test data into validation and test sets
valid, test = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=42)

img_size = (224, 224)
batch_size = 16

# ImageDataGenerators
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
valid_gen = ts_gen.flow_from_dataframe(valid, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen = ts_gen.flow_from_dataframe(test, x_col='filepaths', y_col='label', target_size=img_size,
                                      class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)

img_shape = (img_size[0], img_size[1], 3)
classes = train_gen.class_indices
num_class = len(classes)

# Using ResNet50 as base model
base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(256, kernel_regularizer=regularizers.l2(0.016), activity_regularizer=regularizers.l1(0.006),
          bias_regularizer=regularizers.l1(0.006), activation='relu'),
    Dropout(rate=0.4, seed=75),
    Dense(num_class, activation='softmax')
])

model.compile(Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc = model.evaluate(test_gen, verbose=0)
        print(f'\nTesting loss: {test_loss}, Testing accuracy: {test_acc}\n')

Epochs = 30
history = model.fit(x=train_gen, epochs=Epochs, verbose=1, validation_data=valid_gen,
                    validation_steps=None, shuffle=False, callbacks=[TestAccuracyCallback()])

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i + 1 for i in range(len(train_acc))]

loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'

# Training history
plt.figure(figsize=(20, 8))
plt.style.use('ggplot')

plt.subplot(1, 2, 1)
plt.plot(Epochs, train_loss, 'r', label='Training Loss')
plt.plot(Epochs, val_loss, 'g', label='Validation Loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, train_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, val_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

train_score = model.evaluate(train_gen, steps=16, verbose=1)
valid_score = model.evaluate(valid_gen, steps=16, verbose=1)
test_score = model.evaluate(test_gen, steps=16, verbose=1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])

preds = model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)

g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize=(10, 10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

print(classification_report(test_gen.classes, y_pred, target_names=classes))
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ ?                      │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 23,534,592 (89.78 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.3437
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9757 - loss: 0.3362
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9895 - loss: 0.3439
# Train Loss:  0.3473309874534607
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.3085789978504181
# Validation Accuracy:  0.98828125
# --------------------
# Test Loss:  0.34190845489501953
# Test Accuracy:  0.98828125
#  5/41 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# W0000 00:00:1718080371.042042     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.99      0.99       149
#   meningioma       0.98      0.97      0.97       148
#      notumor       0.98      1.00      0.99       208
#    pituitary       0.99      0.99      0.99       151
#
#     accuracy                           0.99       656
#    macro avg       0.99      0.99      0.99       656
# weighted avg       0.99      0.99      0.99       656

# %% [markdown]
# **alexnet**

# %%
import os
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax

sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# Paths to your training and testing data
train_data_path = '/kaggle/input/brain-tumor-mri-dataset/Training'
test_data_path = '/kaggle/input/brain-tumor-mri-dataset/Testing'

# Create dataframes for training and testing data
def create_dataframe(data_path):
    filepaths = []
    labels = []
    folds = os.listdir(data_path)
    for fold in folds:
        f_path = os.path.join(data_path, fold)
        filelists = os.listdir(f_path)
        for file in filelists:
            filepaths.append(os.path.join(f_path, file))
            labels.append(fold)
    Fseries = pd.Series(filepaths, name='filepaths')
    Lseries = pd.Series(labels, name='label')
    return pd.concat([Fseries, Lseries], axis=1)

train_df = create_dataframe(train_data_path)
test_df = create_dataframe(test_data_path)

# Split test data into validation and test sets
valid, test = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=42)

img_size = (224, 224)
batch_size = 16

# ImageDataGenerators
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
valid_gen = ts_gen.flow_from_dataframe(valid, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen = ts_gen.flow_from_dataframe(test, x_col='filepaths', y_col='label', target_size=img_size,
                                      class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)

img_shape = (img_size[0], img_size[1], 3)
classes = train_gen.class_indices
num_class = len(classes)

# Define AlexNet-like model
model = Sequential([
    Conv2D(96, kernel_size=(11, 11), strides=(4, 4), activation='relu', input_shape=img_shape),
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2)),
    BatchNormalization(),

    Conv2D(384, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(384, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2)),
    BatchNormalization(),

    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(num_class, activation='softmax')
])

model.compile(Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc = model.evaluate(test_gen, verbose=0)
        print(f'\nTesting loss: {test_loss}, Testing accuracy: {test_acc}\n')

Epochs = 30
history = model.fit(x=train_gen, epochs=Epochs, verbose=1, validation_data=valid_gen,
                    validation_steps=None, shuffle=False, callbacks=[TestAccuracyCallback()])

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i + 1 for i in range(len(train_acc))]

loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'

# Training history
plt.figure(figsize=(20, 8))
plt.style.use('ggplot')

plt.subplot(1, 2, 1)
plt.plot(Epochs, train_loss, 'r', label='Training Loss')
plt.plot(Epochs, val_loss, 'g', label='Validation Loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, train_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, val_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

train_score = model.evaluate(train_gen, steps=16, verbose=1)
valid_score = model.evaluate(valid_gen, steps=16, verbose=1)
test_score = model.evaluate(test_gen, steps=16, verbose=1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])

preds = model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)

g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize=(10, 10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

print(classification_report(test_gen.classes, y_pred, target_names=classes))
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 54, 54, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 26, 26, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 26, 26, 96)     │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 26, 26, 256)    │       614,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 12, 12, 384)    │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 12, 12, 384)    │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None,
#
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9913 - loss: 0.0268 - val_accuracy: 0.9802 - val_loss: 0.1085
# Epoch 30/30
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9927 - loss: 0.0214
# Testing loss: 0.09284981340169907, Testing accuracy: 0.9725610017776489
#
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.9927 - loss: 0.0214 - val_accuracy: 0.9802 - val_loss: 0.0526
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0042
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9677 - loss: 0.0757
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9422 - loss: 0.1949
# Train Loss:  0.004288631957024336
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.06144103780388832
# Validation Accuracy:  0.9765625
# --------------------
# Test Loss:  0.13582605123519897
# Test Accuracy:  0.9609375
#  6/41 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# W0000 00:00:1718080938.459636     114 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.95      0.97      0.96       149
#   meningioma       0.96      0.91      0.94       148
#      notumor       0.99      1.00      1.00       208
#    pituitary       0.97      0.99      0.98       151
#
#     accuracy                           0.97       656
#    macro avg       0.97      0.97      0.97       656
# weighted avg       0.97      0.97      0.97       656

# %% [markdown]
# densenet121

# %%
import os
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax

sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# Paths to your training and testing data
train_data_path = '/kaggle/input/brain-tumor-mri-dataset/Training'
test_data_path = '/kaggle/input/brain-tumor-mri-dataset/Testing'

# Create dataframes for training and testing data
def create_dataframe(data_path):
    filepaths = []
    labels = []
    folds = os.listdir(data_path)
    for fold in folds:
        f_path = os.path.join(data_path, fold)
        filelists = os.listdir(f_path)
        for file in filelists:
            filepaths.append(os.path.join(f_path, file))
            labels.append(fold)
    Fseries = pd.Series(filepaths, name='filepaths')
    Lseries = pd.Series(labels, name='label')
    return pd.concat([Fseries, Lseries], axis=1)

train_df = create_dataframe(train_data_path)
test_df = create_dataframe(test_data_path)

# Split test data into validation and test sets
valid, test = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=42)

img_size = (224, 224)
batch_size = 16

# ImageDataGenerators
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
valid_gen = ts_gen.flow_from_dataframe(valid, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen = ts_gen.flow_from_dataframe(test, x_col='filepaths', y_col='label', target_size=img_size,
                                      class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)

img_shape = (img_size[0], img_size[1], 3)
classes = train_gen.class_indices
num_class = len(classes)

# Load DenseNet121 model
base_model = tf.keras.applications.DenseNet121(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

# Add custom layers on top of DenseNet121 base
model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(256, kernel_regularizer=tf.keras.regularizers.l2(0.016), activity_regularizer=tf.keras.regularizers.l1(0.006),
          bias_regularizer=tf.keras.regularizers.l1(0.006), activation='relu'),
    Dropout(rate=0.4, seed=75),
    Dense(num_class, activation='softmax')
])

model.compile(Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc = model.evaluate(test_gen, verbose=0)
        print(f'\nTesting loss: {test_loss}, Testing accuracy: {test_acc}\n')

Epochs = 30
history = model.fit(x=train_gen, epochs=Epochs, verbose=1, validation_data=valid_gen,
                    validation_steps=None, shuffle=False, callbacks=[TestAccuracyCallback()])

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i + 1 for i in range(len(train_acc))]

loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'

# Training history
plt.figure(figsize=(20, 8))
plt.style.use('ggplot')

plt.subplot(1, 2, 1)
plt.plot(Epochs, train_loss, 'r', label='Training Loss')
plt.plot(Epochs, val_loss, 'g', label='Validation Loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, train_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, val_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

train_score = model.evaluate(train_gen, steps=16, verbose=1)
valid_score = model.evaluate(valid_gen, steps=16, verbose=1)
test_score = model.evaluate(test_gen, steps=16, verbose=1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])

preds = model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)

g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize=(10, 10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

30
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9533 - loss: 0.3238
# Testing loss: 0.5208126306533813, Testing accuracy: 0.9847561120986938
#
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 44s 124ms/step - accuracy: 0.9533 - loss: 0.3239 - val_accuracy: 0.9878 - val_loss: 0.5904
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.8338
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 0.6044
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9798 - loss: 0.7783
# Train Loss:  0.9085745811462402
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.4437275230884552
# Validation Accuracy:  1.0
# --------------------
# Test Loss:  0.7230100631713867
# Test Accuracy:  0.9765625
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.99      0.99       149
#   meningioma       0.95      0.99      0.97       148
#      notumor       0.99      1.00      1.00       208
#    pituitary       0.99      0.96      0.98       151
#
#     accuracy                           0.98       656
#    macro avg       0.98      0.98      0.98       656
# weighted avg       0.99      0.98      0.98       656

# %% [markdown]
# **nasanet**

# %%
import os
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax

sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# Paths to your training and testing data
train_data_path = '/kaggle/input/brain-tumor-mri-dataset/Training'
test_data_path = '/kaggle/input/brain-tumor-mri-dataset/Testing'

# Create dataframes for training and testing data
def create_dataframe(data_path):
    filepaths = []
    labels = []
    folds = os.listdir(data_path)
    for fold in folds:
        f_path = os.path.join(data_path, fold)
        filelists = os.listdir(f_path)
        for file in filelists:
            filepaths.append(os.path.join(f_path, file))
            labels.append(fold)
    Fseries = pd.Series(filepaths, name='filepaths')
    Lseries = pd.Series(labels, name='label')
    return pd.concat([Fseries, Lseries], axis=1)

train_df = create_dataframe(train_data_path)
test_df = create_dataframe(test_data_path)

# Split test data into validation and test sets
valid, test = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=42)

img_size = (331, 331)  # NASNetLarge requires larger input size
batch_size = 16

# ImageDataGenerators
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
valid_gen = ts_gen.flow_from_dataframe(valid, x_col='filepaths', y_col='label', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen = ts_gen.flow_from_dataframe(test, x_col='filepaths', y_col='label', target_size=img_size,
                                      class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)

img_shape = (img_size[0], img_size[1], 3)
classes = train_gen.class_indices
num_class = len(classes)

# Load NASNetLarge model
base_model = tf.keras.applications.NASNetLarge(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')

# Add custom layers on top of NASNetLarge base
model = Sequential([
    base_model,
    BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
    Dense(256, kernel_regularizer=tf.keras.regularizers.l2(0.016), activity_regularizer=tf.keras.regularizers.l1(0.006),
          bias_regularizer=tf.keras.regularizers.l1(0.006), activation='relu'),
    Dropout(rate=0.4, seed=75),
    Dense(num_class, activation='softmax')
])

model.compile(Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_acc = model.evaluate(test_gen, verbose=0)
        print(f'\nTesting loss: {test_loss}, Testing accuracy: {test_acc}\n')

Epochs = 30
history = model.fit(x=train_gen, epochs=Epochs, verbose=1, validation_data=valid_gen,
                    validation_steps=None, shuffle=False, callbacks=[TestAccuracyCallback()])

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i + 1 for i in range(len(train_acc))]

loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'

# Training history
plt.figure(figsize=(20, 8))
plt.style.use('ggplot')

plt.subplot(1, 2, 1)
plt.plot(Epochs, train_loss, 'r', label='Training Loss')
plt.plot(Epochs, val_loss, 'g', label='Validation Loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, train_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, val_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

train_score = model.evaluate(train_gen, steps=16, verbose=1)
valid_score = model.evaluate(valid_gen, steps=16, verbose=1)
test_score = model.evaluate(test_gen, steps=16, verbose=1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])

preds = model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)

g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize=(10, 10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

print(classification_report(test_gen.classes, y_pred, target_names=classes))
